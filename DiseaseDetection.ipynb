# %%
from naiveBayesClassifier import tokenizer
from naiveBayesClassifier.trainer import Trainer
from naiveBayesClassifier.classifier import Classifier
import pandas as pd

# %%
#Trainer init
model_trainer = Trainer(tokenizer)

# %%
#Reading Dataset
df=pd.read_csv('data/data.csv')
df.head()
# Out:
#                x      y
# 0          fever  covid
# 1          cough  covid
# 2      tiredness  covid
# 3  loss of taste  covid
# 4  loss of smell  covid

# %%
df
# Out:
#                                 x         y
# 0                           fever     covid
# 1                           cough     covid
# 2                       tiredness     covid
# 3                   loss of taste     covid
# 4                   loss of smell     covid
# 5             shortness of breath     covid
# 6            difficulty breathing     covid
# 7                    muscle aches     covid
# 8                          chills     covid
# 9                     sore throat     covid
# 10                     runny nose     covid
# 11                       headache     covid
# 12                     chest pain     covid
# 13                       pink eye     covid
# 14                         nausea     covid
# 15                       vomiting     covid
# 16                       diarrhea     covid
# 17                           rash     covid
# 18                     old_adults     covid
# 19                          fever   malaria
# 20                         chills   malaria
# 21                     old_adults   malaria
# 22  general feeling of discomfort   malaria
# 23                       Headache   malaria
# 24            nausea and vomiting   malaria
# 25                       diarrhea   malaria
# 26                 abdominal pain   malaria
# 27           muscle or joint pain   malaria
# 28                        fatigue   malaria
# 29                rapid breathing   malaria
# 30               rapid heart rate   malaria
# 31                          cough   malaria
# 32                       polyuria  diabetes
# 33                     polydypsia  diabetes
# 34            shortness of breath  diabetes
# 35                     pain chest  diabetes
# 36                       asthenia  diabetes
# 37                         nausea  diabetes
# 38                      orthopnea  diabetes
# 39                           rale  diabetes
# 40       sweat sweating increased  diabetes
# 41               unresponsiveness  diabetes
# 42          mental status changes  diabetes
# 43                        vertigo  diabetes
# 44                       vomiting  diabetes
# 45              labored breathing  diabetes

# %%
model= Classifier(model_trainer.data, tokenizer)

# %%
def age_group(age):
    if age<=2:
        return "baby"
    elif age>=3 and age<=39:
        return "young_adult"
    elif age>=40 and age<=59:
        return "middle_aged_adults"
    elif age>=60:
        return "old_adults"

# %%
print ("Please enter your Name:")
name=input()
print ("Please enter your Age:")
age=float(input())
print ("Please enter your Symptoms:")
symptoms=input()
# Out:
# Please enter your Name:
# Please enter your Age:
# Please enter your Symptoms:

# %%
disease=model.classify(symptoms+" "+age_group(age))

# %%
print(dict(enumerate(disease)))
# Out:
# {0: 'diabetes', 1: 'covid', 2: 'malaria'}
